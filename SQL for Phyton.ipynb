# %% [markdown]
# # SQL MAGIC

# %% [markdown]
# ## 1. Load SQL extension

# %%
# %load_ext sql

# %% [markdown]
# ## 2. Connect database

# %%
# %sql example #example=link of the database

# %% [markdown]
# ##  3. Simple SQL codes can be executed through SQL Magic

# %%
# %%sql
#
# select * from example_table
